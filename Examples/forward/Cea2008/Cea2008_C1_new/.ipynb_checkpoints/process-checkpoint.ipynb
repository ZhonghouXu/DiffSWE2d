# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
q_file = "bottom_boundary_discharge.txt"
h_file = "gauge_0.txt"

# %%
q_data = pd.read_csv(q_file, skiprows=0, sep=' ', header=0)
h_data = pd.read_csv(h_file, skiprows=1, sep=' ', header=0)

# %%
plt.plot(q_data["Time(s)"],q_data["Discharge(m3/s)"])

# %%
import xarray as xr

# %%
ds = xr.open_dataset("hmax.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 416kB
# Dimensions:  (y: 255, x: 202)
# Coordinates:
#   * y        (y) float64 2kB 0.005 0.015 0.025 0.035 ... 2.515 2.525 2.535 2.545
#   * x        (x) float64 2kB 0.005 0.015 0.025 0.035 ... 1.985 1.995 2.005 2.015
# Data variables:
#     hmax     (y, x) float64 412kB ...
# Attributes:
#     description:  Maximum water depth
#     units:        metres

# %%
plt.pcolormesh(ds["x"],ds["y"],ds["hmax"])
plt.gca().set_aspect('equal', adjustable='box')
